# %%
#CÓDIGO 01
library(here) 

R.home() 

readRenviron (here(".env")) 

Sys.getenv ("name") 
Sys.getenv ("uem_id" ) 
seed = as.integer (Sys.getenv ("seed")) 

set.seed (seed)
# Out:
# here() starts at /home/mario/reposicionamiento
# [1] "/home/mario/reposicionamiento/.venvs/r/lib/R"
# [1] "Mario Brea"
# [1] "224D2000"
