# %%
#CÓDIGO 01
library(here) 

R.home() 

readRenviron (here(".env")) 

Sys.getenv ("name") 
Sys.getenv ("uem_id" ) 
seed = as.integer (Sys.getenv ("seed")) 

set.seed (seed)
# Out:
# here() starts at /home/mario/reposicionamiento
# [1] "/home/mario/reposicionamiento/.venvs/r/lib/R"
# [1] "Mario Brea"
# [1] "224D2000"

# %%
#DESCARGA DE DATOS DE DRUGBANK Y DISGENET 
source(here("src","r","utils.r"))

download_data(get_drugbank_url(), here("data","raw","drugbank.xml.gz"))
download_data(get_disgenet_url(), here("data","raw","curated_gene_disease_associations.tsv.gz"))

list.files(here("data","raw"))
# Out:
# [1] "/home/mario/reposicionamiento/data/raw/drugbank.xml.gz"
# [1] "/home/mario/reposicionamiento/data/raw/curated_gene_disease_associations.tsv.gz"
# [1] "curated_gene_disease_associations.tsv.gz"
# [2] "drugbank.xml.gz"
